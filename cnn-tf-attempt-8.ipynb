# %% [markdown]
# # Dog Image Mood Classification
#
# > Using Convolutional Neural Network Deep Learning model

# %% [markdown]
# ### Params

# %%
IMAGE_SIZE = 384
NUM_CHANELLS = 3
LEN_FEATURES = IMAGE_SIZE * IMAGE_SIZE * NUM_CHANELLS
NUM_OF_EPOCHS = 50
ZISE_OF_IMAGES = 9000
BATCH_SIZE = 32
LEARNING_RATE = 0.0000001
CLASSES = ['happy', 'sad']

# %% [markdown]
# ### Paths

# %%
PATH = r"D:\\Projects\Development\\courses_projects\\deep_learning_and_natural_language_processing\\dog-image-mood-classification"
PATH_TO_DATA = PATH + '\\' + "data\\images"
RES_PATH = r"results\\"
MODEL_HISTORY_FILEPATH = r"D:\\Projects\\Development\\courses_projects\\deep_learning_and_natural_language_processing\\dog-image-mood-classification\\models_history\\model_4.hdf5"

# %% [markdown]
# ### Importing

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "8"

# %%
# modeling
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.utils import shuffle
import cv2

# tools
from typing import Tuple
import os
import random
import numpy as np
from datetime import datetime

# warnings
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %% [markdown]
# ### Util Functions

# %%
def load_data(classes) -> Tuple[np.array, np.array]:
  images = []
  labels = []
  files = []
  for i in range(len(classes)):
    folder_name = classes[i]
    path = os.path.join(PATH_TO_DATA, folder_name)
    count = 0
    for file_index, file_name in enumerate(os.listdir(path)):
      file_name = os.path.join(path, file_name)
      image = cv2.imread(file_name)
      images.append(image)
      label = [i]
      labels.append(label)
      files.append(os.path.join(path, file_name))
      if count == ZISE_OF_IMAGES / len(CLASSES):
        break
      count += 1
  return np.array(images), np.array(labels)

# %% [markdown]
# ### Load Data

# %%
train_images, train_labels = load_data(CLASSES)
train_images, train_labels = shuffle(train_images, train_labels)

# %%
print(f"Shape of training data: {train_images.shape}")
# Out:
# Shape of training data: (9002, 384, 384, 3)

# %%
print(f"Size of train: {len(train_images)}")
# Out:
# Size of train: 9002

# %%
x_train = train_images.astype('float32') / 255.0
y_train = np.asarray(train_labels).astype('float32').reshape((-1,1))

# %% [markdown]
# ### Build Model

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(96, (3, 3), strides=(2, 2), padding='valid', activation='relu', input_shape=x_train.shape[1:]))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

model.add(tf.keras.layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

model.add(tf.keras.layers.Conv2D(384, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(3, 2)))

model.add(tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.GlobalAveragePooling2D())

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(4096, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE), loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 191, 191, 96)      2688
#
#  batch_normalization (BatchN  (None, 191, 191, 96)     384
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 95, 95, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 256)       221440
#
#  batch_normalization_1 (Batc  (None, 48, 48, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 23, 23, 384)      1536
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 23, 23, 256)       884992
#
#  batch_normalization_3 (Batc  (None, 23, 23, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 11, 256)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 11, 256)        590080
#
#  dropout (Dropout)           (None, 7, 11, 256)        0
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dense_1 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 3,645,057
# Trainable params: 3,643,073
# Non-trainable params: 1,984
# _________________________________________________________________

# %% [markdown]
# ### Train Model

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=MODEL_HISTORY_FILEPATH,
    monitor='val_accuracy',
    mode='auto',
    save_best_only=True
    )

train_scores = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=NUM_OF_EPOCHS, shuffle=True, validation_split=0.2, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/50
# 226/226 [==============================] - 746s 3s/step - loss: 0.6910 - accuracy: 0.5241 - val_loss: 0.6932 - val_accuracy: 0.5031
# Epoch 2/50
# 226/226 [==============================] - 742s 3s/step - loss: 0.6869 - accuracy: 0.5433 - val_loss: 0.6914 - val_accuracy: 0.5358
# Epoch 3/50
# 226/226 [==============================] - 746s 3s/step - loss: 0.6840 - accuracy: 0.5533 - val_loss: 0.6833 - val_accuracy: 0.5602
# Epoch 4/50
# 226/226 [==============================] - 746s 3s/step - loss: 0.6813 - accuracy: 0.5645 - val_loss: 0.6789 - val_accuracy: 0.5736
# Epoch 5/50
# 226/226 [==============================] - 742s 3s/step - loss: 0.6792 - accuracy: 0.5696 - val_loss: 0.6766 - val_accuracy: 0.5769
# Epoch 6/50
# 226/226 [==============================] - 744s 3s/step - loss: 0.6771 - accuracy: 0.5709 - val_loss: 0.6748 - val_accuracy: 0.5830
# Epoch 7/50
# 226/226 [==============================] - 742s 3s/step - loss: 0.6757 - accuracy: 0.5713 - val_loss: 0.6733 - val_accuracy: 0.5825
# Epoch 8/50
# 226/226 [==============================] - 743s 3s/step - loss: 0.6740 - accuracy: 0.5769 - val_loss: 0.6718 - val_accuracy: 0.5891
# Epoch 9/50
# 226/226 [==============================] - 741s 3s/step - loss: 0.6719 - accuracy: 0.5851 - val_loss: 0.6705 - val_accuracy: 0.5897
# Epoch 10/50
# 226/226 [==============================] - 741s 3s/step - loss: 0.6714 - accuracy: 0.5809 - val_loss: 0.6696 - val_accuracy: 0.5958
# Epoch 11/50
# 226/226 [==============================] - 738s 3s/step - loss: 0.6688 - accuracy: 0.5955 - val_loss: 0.6685 - val_accuracy: 0.5952
# Epoch 12/50
# 226/226 [==============================] - 739s 3s/step - loss: 0.6687 - accuracy: 0.5876 - val_loss: 0.6675 - val_accuracy: 0.5963
# Epoch 13/50
# 226/226 [==============================] - 738s 3s/step - loss: 0.6672 - accuracy: 0.5873 - val_loss: 0.6668 - val_accuracy: 0.5941
# Epoch 14/50
# 226/226 [==============================] - 739s 3s/step - loss: 0.6670 - accuracy: 0.5927 - val_loss: 0.6659 - val_accuracy: 0.5936
# Epoch 15/50
# 226/226 [==============================] - 738s 3s/step - loss: 0.6671 - accuracy: 0.5908 - val_loss: 0.6652 - val_accuracy: 0.5936
# Epoch 16/50
# 226/226 [==============================] - 739s 3s/step - loss: 0.6654 - accuracy: 0.5933 - val_loss: 0.6647 - val_accuracy: 0.5986
# Epoch 17/50
# 226/226 [==============================] - 736s 3s/step - loss: 0.6644 - accuracy: 0.5953 - val_loss: 0.6640 - val_accuracy: 0.5980
# Epoch 18/50
# 226/226 [==============================] - 738s 3s/step - loss: 0.6638 - accuracy: 0.6001 - val_loss: 0.6635 - val_accuracy: 0.6002
# Epoch 19/50
# 226/226 [==============================] - 737s 3s/step - loss: 0.6636 - accuracy: 0.5962 - val_loss: 0.6630 - val_accuracy: 0.5980
# Epoch 20/50
# 226/226 [==============================] - 735s 3s/step - loss: 0.6630 - accuracy: 0.5955 - val_loss: 0.6625 - val_accuracy: 0.5986
# Epoch 21/50
# 226/226 [==============================] - 736s 3s/step - loss: 0.6612 - accuracy: 0.6026 - val_loss: 0.6621 - val_accuracy: 0.6013
# Epoch 22/50
# 226/226 [==============================] - 735s 3s/step - loss: 0.6618 - accuracy: 0.6002 - val_loss: 0.6617 - val_accuracy: 0.6036
# Epoch 23/50
# 226/226 [==============================] - 736s 3s/step - loss: 0.6602 - accuracy: 0.6041 - val_loss: 0.6613 - val_accuracy: 0.6063
# Epoch 24/50
# 226/226 [==============================] - 736s 3s/step - loss: 0.6588 - accuracy: 0.6052 - val_loss: 0.6609 - val_accuracy: 0.6036
# Epoch 25/50
# 226/226 [==============================] - 739s 3s/step - loss: 0.6603 - accuracy: 0.6027 - val_loss: 0.6607 - val_accuracy: 0.6069
# Epoch 26/50
# 226/226 [==============================] - 737s 3s/step - loss: 0.6586 - accuracy: 0.6057 - val_loss: 0.6604 - val_accuracy: 0.6113
# Epoch 27/50
# 226/226 [==============================] - 737s 3s/step - loss: 0.6587 - accuracy: 0.6017 - val_loss: 0.6600 - val_accuracy: 0.6091
# Epoch 28/50
# 226/226 [==============================] - 733s 3s/step - loss: 0.6573 - accuracy: 0.6088 - val_loss: 0.6598 - val_accuracy: 0.6091
# Epoch 29/50
# 226/226 [==============================] - 737s 3s/step - loss: 0.6569 - accuracy: 0.6082 - val_loss: 0.6594 - val_accuracy: 0.6119
# Epoch 30/50
# 226/226 [==============================] - 736s 3s/step - loss: 0.6561 - accuracy: 0.6127 - val_loss: 0.6593 - val_accuracy: 0.6102
# Epoch 31/50
# 226/226 [==============================] - 734s 3s/step - loss: 0.6564 - accuracy: 0.6109 - val_loss: 0.6590 - val_accuracy: 0.6102
# Epoch 32/50
# 226/226 [==============================] - 735s 3s/step - loss: 0.6564 - accuracy: 0.6077 - val_loss: 0.6588 - val_accuracy: 0.6113
# Epoch 33/50
# 226/226 [==============================] - 732s 3s/step - loss: 0.6556 - accuracy: 0.6156 - val_loss: 0.6585 - val_accuracy: 0.6086
# Epoch 34/50
# 226/226 [==============================] - 733s 3s/step - loss: 0.6551 - accuracy: 0.6124 - val_loss: 0.6584 - val_accuracy: 0.6108
# Epoch 35/50
# 226/226 [==============================] - 735s 3s/step - loss: 0.6544 - accuracy: 0.6153 - val_loss: 0.6581 - val_accuracy: 0.6091
# Epoch 36/50
# 226/226 [==============================] - 734s 3s/step - loss: 0.6547 - accuracy: 0.6113 - val_loss: 0.6578 - val_accuracy: 0.6113
# Epoch 37/50
# 226/226 [==============================] - 734s 3s/step - loss: 0.6531 - accuracy: 0.6141 - val_loss: 0.6578 - val_accuracy: 0.6147
# Epoch 38/50
# 226/226 [==============================] - 736s 3s/step - loss: 0.6523 - accuracy: 0.6188 - val_loss: 0.6575 - val_accuracy: 0.6163
# Epoch 39/50
# 226/226 [==============================] - 736s 3s/step - loss: 0.6531 - accuracy: 0.6116 - val_loss: 0.6575 - val_accuracy: 0.6163
# Epoch 40/50
# 226/226 [==============================] - 737s 3s/step - loss: 0.6525 - accuracy: 0.6144 - val_loss: 0.6573 - val_accuracy: 0.6169
# Epoch 41/50
# 226/226 [==============================] - 733s 3s/step - loss: 0.6501 - accuracy: 0.6212 - val_loss: 0.6572 - val_accuracy: 0.6180
# Epoch 42/50
# 226/226 [==============================] - 735s 3s/step - loss: 0.6518 - accuracy: 0.6138 - val_loss: 0.6568 - val_accuracy: 0.6180
# Epoch 43/50
# 226/226 [==============================] - 735s 3s/step - loss: 0.6500 - accuracy: 0.6234 - val_loss: 0.6567 - val_accuracy: 0.6174
# Epoch 44/50
# 226/226 [==============================] - 734s 3s/step - loss: 0.6504 - accuracy: 0.6173 - val_loss: 0.6566 - val_accuracy: 0.6180
# Epoch 45/50
# 226/226 [==============================] - 736s 3s/step - loss: 0.6499 - accuracy: 0.6219 - val_loss: 0.6566 - val_accuracy: 0.6202
# Epoch 46/50
# 226/226 [==============================] - 735s 3s/step - loss: 0.6499 - accuracy: 0.6202 - val_loss: 0.6563 - val_accuracy: 0.6191
# Epoch 47/50
# 226/226 [==============================] - 733s 3s/step - loss: 0.6486 - accuracy: 0.6156 - val_loss: 0.6563 - val_accuracy: 0.6197
# Epoch 48/50
# 226/226 [==============================] - 732s 3s/step - loss: 0.6491 - accuracy: 0.6195 - val_loss: 0.6561 - val_accuracy: 0.6197
# Epoch 49/50
# 226/226 [==============================] - 733s 3s/step - loss: 0.6478 - accuracy: 0.6207 - val_loss: 0.6559 - val_accuracy: 0.6180
# Epoch 50/50
# 226/226 [==============================] - 733s 3s/step - loss: 0.6480 - accuracy: 0.6284 - val_loss: 0.6559 - val_accuracy: 0.6224

# %% [markdown]
# ### Results

# %%
plt.title("Train Loss and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(np.arange(NUM_OF_EPOCHS), train_scores.history['loss'])
plt.plot(np.arange(NUM_OF_EPOCHS), train_scores.history['val_loss'])
plt.legend(["Train loss", "Validation loss"])
plt.show()

# %%
plt.title("Train accuracy and Validation accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(np.arange(NUM_OF_EPOCHS), train_scores.history['accuracy'])
plt.plot(np.arange(NUM_OF_EPOCHS), train_scores.history['val_accuracy'])
plt.legend(["Train accuracy", "Validation accuracy"])
plt.show()

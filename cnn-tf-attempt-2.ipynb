# %%
# params
IMAGE_SIZE = 227
NUM_CHANELLS = 3
LEN_FEATURES = IMAGE_SIZE * IMAGE_SIZE * NUM_CHANELLS
NUM_OF_EPOCHS = 30
ZISE_OF_IMAGES = 6000
BATCH_SIZE = 64
LEARNING_RATE = 0.000001
CLASSES = ['happy', 'sad']

# paths
PATH = r"D:\\Projects\Development\\courses_projects\\deep_learning_and_natural_language_processing\\dog-image-mood-classification"
PATH_TO_DATA = PATH + '\\' + "data\\images"
MODEL_HISTORY_FILEPATH =  + PATH + "\\" + r"models_history\\model_1.hdf5"

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "8"

# %%
# modeling
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.utils import shuffle
import cv2

# tools
from typing import Tuple
import os
import random
import numpy as np
from datetime import datetime

# warnings
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
def load_data(classes) -> Tuple[np.array, np.array]:
  images = []
  labels = []
  files = []
  for i in range(len(classes)):
    folder_name = classes[i]
    path = os.path.join(PATH_TO_DATA, folder_name)
    count = 0
    for file_index, file_name in enumerate(os.listdir(path)):
      file_name = os.path.join(path, file_name)
      image = cv2.imread(file_name)
      image = cv2.resize(image, (IMAGE_SIZE, IMAGE_SIZE))
      images.append(image)
      label = [i]
      labels.append(label)
      files.append(os.path.join(path, file_name))
      if count == ZISE_OF_IMAGES / 2:
        break
      count += 1
  return np.array(images), np.array(labels)

def plot_images(images, cls_true, cls_pred=None):
    if len(images) == 0:
        print("no images to show")
        return 
    else:
        random_indices = random.sample(range(len(images)), min(len(images), 9))
        
    if cls_pred is not None:
        images, cls_true, cls_pred  = zip(*[(images[i], cls_true[i], cls_pred[i]) for i in random_indices])
    else:
        images, cls_true  = zip(*[(images[i], cls_true[i]) for i in random_indices])
    
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i].reshape(IMAGE_SIZE, IMAGE_SIZE, 3))

        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])
    plt.show()

def make_vactors(labels) -> np.array:
  new_labels = []
  for label in labels:
      value = label[0]
      new_label = [0] * len(CLASSES)
      new_label[value] = 1
      new_labels.append(new_label)
  return np.array(new_labels)

# %%
train_images, train_labels = load_data(CLASSES)
train_images, train_labels = shuffle(train_images, train_labels)

# %%
print(f"Shape of training data: {train_images.shape}")
# Out:
# Shape of training data: (6002, 224, 224, 3)

# %%
print(f"Size of train: {len(train_images)}")
# Out:
# Size of train: 6002

# %%
x_train = train_images.astype('float32') / 255.0
y_train = np.asarray(train_labels).astype('float32').reshape((-1,1))

# %%
# AlexNet Model archicture
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(96, (11, 11), padding='valid', activation='relu', input_shape=x_train.shape[1:]))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3, 3)))
model.add(tf.keras.layers.Conv2D(256, (5, 5), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3, 3)))
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Conv2D(384 (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(384, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(4096, activation='relu'))
model.add(tf.keras.layers.Dense(4096, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizer.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 110, 110, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 55, 55, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 55, 55, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 55, 55, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 53, 53, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 26, 26, 64)        0
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dense (Dense)               (None, 512)               22151680
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 22,217,761
# Trainable params: 22,217,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=MODEL_HISTORY_FILEPATH,
    monitor='val_accuracy',
    mode='auto',
    save_best_only=True
    )

train_scores = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=NUM_OF_EPOCHS, shuffle=True, validation_split=0.2, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/50
# 76/76 [==============================] - 169s 2s/step - loss: 0.8120 - accuracy: 0.5091 - val_loss: 0.6934 - val_accuracy: 0.4821
# Epoch 2/50
# 76/76 [==============================] - 163s 2s/step - loss: 0.6936 - accuracy: 0.5061 - val_loss: 0.6935 - val_accuracy: 0.4813
# Epoch 3/50
# 76/76 [==============================] - 169s 2s/step - loss: 0.6927 - accuracy: 0.5155 - val_loss: 0.6918 - val_accuracy: 0.5279
# Epoch 4/50
# 76/76 [==============================] - 164s 2s/step - loss: 0.6903 - accuracy: 0.5276 - val_loss: 0.6922 - val_accuracy: 0.5087
# Epoch 5/50
# 76/76 [==============================] - 169s 2s/step - loss: 0.6921 - accuracy: 0.5474 - val_loss: 0.6916 - val_accuracy: 0.5437
# Epoch 6/50
# 76/76 [==============================] - 167s 2s/step - loss: 0.6884 - accuracy: 0.5449 - val_loss: 0.6862 - val_accuracy: 0.5654
# Epoch 7/50
# 76/76 [==============================] - 168s 2s/step - loss: 0.6812 - accuracy: 0.5665 - val_loss: 0.6809 - val_accuracy: 0.5729
# Epoch 8/50
# 76/76 [==============================] - 167s 2s/step - loss: 0.6658 - accuracy: 0.5993 - val_loss: 0.6785 - val_accuracy: 0.5837
# Epoch 9/50
# 76/76 [==============================] - 163s 2s/step - loss: 0.6676 - accuracy: 0.6007 - val_loss: 0.6830 - val_accuracy: 0.5754
# Epoch 10/50
# 76/76 [==============================] - 167s 2s/step - loss: 0.6375 - accuracy: 0.6361 - val_loss: 0.6697 - val_accuracy: 0.6020
# Epoch 11/50
# 76/76 [==============================] - 163s 2s/step - loss: 0.6013 - accuracy: 0.6738 - val_loss: 0.6916 - val_accuracy: 0.5920
# Epoch 12/50
# 76/76 [==============================] - 167s 2s/step - loss: 0.5368 - accuracy: 0.7317 - val_loss: 0.7290 - val_accuracy: 0.5803
# Epoch 13/50
# 76/76 [==============================] - 163s 2s/step - loss: 0.3959 - accuracy: 0.8161 - val_loss: 0.8331 - val_accuracy: 0.5895
# Epoch 14/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.2397 - accuracy: 0.9061 - val_loss: 1.1084 - val_accuracy: 0.6020
# Epoch 15/50
# 76/76 [==============================] - 163s 2s/step - loss: 0.1366 - accuracy: 0.9554 - val_loss: 1.3190 - val_accuracy: 0.5787
# Epoch 16/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0788 - accuracy: 0.9783 - val_loss: 1.7541 - val_accuracy: 0.5803
# Epoch 17/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0567 - accuracy: 0.9835 - val_loss: 1.8093 - val_accuracy: 0.5928
# Epoch 18/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0473 - accuracy: 0.9890 - val_loss: 1.8338 - val_accuracy: 0.5920
# Epoch 19/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0699 - accuracy: 0.9800 - val_loss: 1.8288 - val_accuracy: 0.5687
# Epoch 20/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0974 - accuracy: 0.9694 - val_loss: 1.6302 - val_accuracy: 0.5812
# Epoch 21/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0362 - accuracy: 0.9933 - val_loss: 1.8369 - val_accuracy: 0.5845
# Epoch 22/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0209 - accuracy: 0.9956 - val_loss: 1.9107 - val_accuracy: 0.5987
# Epoch 23/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0218 - accuracy: 0.9958 - val_loss: 1.8816 - val_accuracy: 0.5903
# Epoch 24/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0139 - accuracy: 0.9954 - val_loss: 2.0668 - val_accuracy: 0.5887
# Epoch 25/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0233 - accuracy: 0.9954 - val_loss: 2.0206 - val_accuracy: 0.5770
# Epoch 26/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0176 - accuracy: 0.9956 - val_loss: 1.9410 - val_accuracy: 0.5779
# Epoch 27/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0171 - accuracy: 0.9958 - val_loss: 1.9366 - val_accuracy: 0.5812
# Epoch 28/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0154 - accuracy: 0.9956 - val_loss: 2.0393 - val_accuracy: 0.5978
# Epoch 29/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0143 - accuracy: 0.9967 - val_loss: 2.0341 - val_accuracy: 0.5878
# Epoch 30/50
# 76/76 [==============================] - 161s 2s/step - loss: 0.0142 - accuracy: 0.9969 - val_loss: 2.0039 - val_accuracy: 0.5928
# Epoch 31/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0124 - accuracy: 0.9971 - val_loss: 2.0714 - val_accuracy: 0.5895
# Epoch 32/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 2.0321 - val_accuracy: 0.5912
# Epoch 33/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 2.0702 - val_accuracy: 0.5928
# Epoch 34/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0114 - accuracy: 0.9971 - val_loss: 2.1521 - val_accuracy: 0.5928
# Epoch 35/50
# 76/76 [==============================] - 161s 2s/step - loss: 0.0097 - accuracy: 0.9971 - val_loss: 2.1043 - val_accuracy: 0.5853
# Epoch 36/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 2.0457 - val_accuracy: 0.5795
# Epoch 37/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 2.1203 - val_accuracy: 0.5903
# Epoch 38/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 2.0857 - val_accuracy: 0.5853
# Epoch 39/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 2.1149 - val_accuracy: 0.5837
# Epoch 40/50
# 76/76 [==============================] - 161s 2s/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 1.9647 - val_accuracy: 0.5937
# Epoch 41/50
# 76/76 [==============================] - 161s 2s/step - loss: 0.0133 - accuracy: 0.9965 - val_loss: 1.9663 - val_accuracy: 0.5878
# Epoch 42/50
# 76/76 [==============================] - 161s 2s/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 1.8604 - val_accuracy: 0.5945
# Epoch 43/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 1.9425 - val_accuracy: 0.5945
# Epoch 44/50
# 76/76 [==============================] - 161s 2s/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 1.9522 - val_accuracy: 0.5870
# Epoch 45/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0066 - accuracy: 0.9971 - val_loss: 2.0504 - val_accuracy: 0.5937
# Epoch 46/50
# 76/76 [==============================] - 161s 2s/step - loss: 0.0060 - accuracy: 0.9971 - val_loss: 2.0574 - val_accuracy: 0.5903
# Epoch 47/50
# 76/76 [==============================] - 161s 2s/step - loss: 0.0063 - accuracy: 0.9973 - val_loss: 2.1259 - val_accuracy: 0.5920
# Epoch 48/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0057 - accuracy: 0.9973 - val_loss: 2.1203 - val_accuracy: 0.5878
# Epoch 49/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0175 - accuracy: 0.9952 - val_loss: 2.0491 - val_accuracy: 0.6020
# Epoch 50/50
# 76/76 [==============================] - 162s 2s/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 2.0392 - val_accuracy: 0.5862

# %%
plt.title("Train Loss and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(np.arange(NUM_OF_EPOCHS), train_scores.history['loss'])
plt.plot(np.arange(NUM_OF_EPOCHS), train_scores.history['val_loss'])
plt.legend(["Train loss", "Validation loss"])
plt.show()

# %%
plt.title("Train accuracy and Validation accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(np.arange(NUM_OF_EPOCHS), train_scores.history['accuracy'])
plt.plot(np.arange(NUM_OF_EPOCHS), train_scores.history['val_accuracy'])
plt.legend(["Train accuracy", "Validation accuracy"])
plt.show()
